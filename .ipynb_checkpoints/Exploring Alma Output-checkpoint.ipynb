# %% [markdown]
# # Exploratory ALMA analysis
#
# This will look through the export from Alma in attempt to make a standardized list of titles.

# %%
import pandas as pd
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
alma_df = pd.read_csv("ALMA_export.csv")

# %%
alma_df.sample(10)
# Out:
#                                                    Title ISSN Valid  \
# 49976              Journal of intellectual disabilities.   17446309
# 39439  International Journal of Sciences and Innovati...   30490251
# 53039  Journal of the advanced practitioner in oncology.   21500886
# 14362                        Bulletin paroissial (Bédée)   25063480
# 18779  Collection of papers presented at the ... Inte...   24741523
# 15799  Canadian index to periodicals and documentary ...   05279259
# 91662             The Saudi journal for dental research.   23520043
# 93889                                         The times.   01400460
# 39986  International journal of academic health and m...   26439824
# 30363  Foristek : forum teknik elektro dan teknologi ...   25797174
#
#                                                Publisher
# 49976                                  SAGE Publications
# 39439  International Journal of Sciences and Innovati...
# ...

# %%
len(alma_df)
# Out:
# 102232

# %%
pubs = pd.DataFrame(alma_df["Publisher"].value_counts())

# %%
#Lots of publishers!
#pubs

# %%
#Build the Regex of publisher names
pub_names = [
    "American Chemical Society",
    "Association for Computing Machinery",
    "Cambridge University Press",
    "Canadian Science Publishing",
    "JMIR",
    "MDPI",
    "Microbiology Society Journals",
    "Oxford University Press",
    "Royal Society of Chemistry",
    "Francis",
    "Wiley",
    ]

# %%
#Search, rename, and count


selected_pub_df = pd.DataFrame()
pub_numbers = []

for pub in pub_names:
    
    sub_pub = alma_df[alma_df["Publisher"].str.contains(pub, regex=True, na=False)]
    sub_pub["Publisher"] = pub
     
    this_pub = alma_df[alma_df["Publisher"].str.contains(pub, regex=True, na=False)]
    pub_details = [pub,len(this_pub)]
    
    pub_numbers.append(pub_details)
    
pub_numbers_df  = pd.DataFrame(pub_numbers)
pub_numbers_df.columns = ["Publisher Name","Count"]

sub_pub
# Out:
# /var/folders/4d/l0hbr18d77q0fbv19d1dmnf40000gn/T/ipykernel_21286/3104921387.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_pub["Publisher"] = pub
#                              Title ISSN Valid Publisher
# 764         ACR open rheumatology.   25785745     Wiley
# 853    AEM education and training.   24725390     Wiley
# 875                  AGU advances.   2576604X     Wiley
# 879               AI & innovation.   30673941     Wiley
# 894                   AI magazine.   23719621     Wiley
# ...                            ...        ...       ...
# 99581                       eFood.   26663066     Wiley
# 99599                     iLABMED.   28344448     Wiley
# 99601                       iMeta.   2770596X     Wiley
# ...

# %%
#Sanity Check
pub_numbers_df
# Out:
#                          Publisher Name  Count
# 0             American Chemical Society    106
# 1   Association for Computing Machinery    135
# 2            Cambridge University Press    530
# 3           Canadian Science Publishing     19
# 4                                  JMIR     24
# 5                                  MDPI    404
# 6         Microbiology Society Journals      0
# 7               Oxford University Press    584
# 8            Royal Society of Chemistry     82
# 9                               Francis   2617
# 10                                Wiley   1876

# %%
#If I want to rename, can't do it all in one shot
#Rename the column entry as well?
#filtered_df = alma_df[alma_df["Publisher"].str.contains(pub_regx, regex=True, na=False)]
#filtered_df.reset_index(drop=True,inplace=True)
